# %%
packet_bytes = [
  
]

# %%
# Get packets starting from 0050 e
image = packet_bytes[0x34:]

# Print hexadecimal values
print(' '.join([f'{x:02x}' for x in image]))
# Out:
# ff d8 ff e0 00 10 4a 46 49 46 00 01 01 00 00 01 00 01 00 00 ff db 00 43 00 05 03 04 04 04 03 05 04 04 04 05 05 05 06 07 0c 08 07 07 07 07 0f 0b 0b 09 0c 11 0f 12 12 11 0f 11 11 13 16 1c 17 13 14 1a 15 11 11 18 21 18 1a 1d 1d 1f 1f 1f 13 17 22 24 22 1e 24 1c 1e 1f 1e ff db 00 43 01 05 05 05 07 06 07 0e 08 08 0e 1e 14 11 14 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e 1e ff c0 00 11 08 00 50 00 50 03 01 22 00 02 11 01 03 11 01 ff c4 00 1d 00 00 01 04 03 01 01 00 00 00 00 00 00 00 00 00 00 08 00 03 07 09 04 05 06 01 02 ff c4 00 43 10 00 01 03 03 02 03 01 0d 06 04 03 09 00 00 00 00 01 02 03 04 05 06 11 00 12 07 13 21 31 08 09 14 16 17 22 37 41 51 56 95 b3 d2 15 33 57 61 75 94 23 32 71 81 26 76 b4 34 38 43 72 73 82 91 a1 b1 ff c4 00 14 01 01 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 ff c4 00 14 11 01 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 ff da 00 0c 03 01 00 02 11 03 11 00
# ...

# %%
# Show image
from PIL import Image
import io
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
img = Image.open(io.BytesIO(bytes(image)))
img.show()
