# %%
packet_bytes = [
   
]

# %%
# Get packets starting from 0050 e
image = packet_bytes[0x34:]

# Print hexadecimal values
print(' '.join([f'{x:02x}' for x in image]))
# Out:
# 2d c7 71 29 29 25 c4 2f 71 dd ea f3 3f f7 a9 1f bd c0 02 b8 a5 71 a5 40 10 68 64 10 7d 7f c7 6b 46 87 88 76 3f b9 96 e7 c2 d9 fa 74 00 b7 11 2f d4 5b fd d5 b4 8e 2d 4f a1 4f 4d 2e 6c 38 55 58 d1 fa 05 ba d3 90 52 9f 35 47 cd 38 51 20 91 eb 49 d6 27 0d 2e 0a d5 c1 c5 8e 27 f1 06 d5 b5 d7 53 4b d4 c9 d2 c4 29 51 4c 86 b6 bc f2 0f 2d d4 a4 e1 59 46 ff 00 34 1e bb 4e 33 8d 1f d3 ed 9b 72 a1 1a 34 69 f4 0a 54 b6 22 23 64 66 df 86 da d2 ca 70 06 10 08 c2 46 00 e8 3d 83 4f 53 28 f4 8a 1c 57 9b a2 d2 a0 53 50 bc ad 68 89 19 0d 25 4a 03 b4 84 81 93 a0 aa 4a 9d 62 d4 99 68 ae 3b 56 a0 81 70 aa 6f 34 4d 8d 2d cf 07 4c 7d bf 75 ca 59 51 dd bb ae ed dd 98 18 d7 4f 77 40 9f 4b af f0 d2 25 52 2b d1 24 a6 8f 0d 6a 69 e4 94 ad 29 54 c7 d4 9c 83 d4 65 2a 49 fe 87 5d 95 8b 7f f1 46 f4 95 5c 8b 6f 5b f6 f5 5a b1 19 b4 c9 65 0c 5b 50 4b 83 f8 c9 4a 97 f7 7d 7f 9b b4 fb 74 d5 3b 8a 3c 76 bd af 27 e9 71 69 34 ca e5 c3 09 2a e6 b6 bb 76 13 af b2 1a 5e d3 d5 4d e4 04 a8 e3 b7 a1 3a 08 e2 8f 67 bf 72 51 af 7a
# ...

# %%
# Show image
from PIL import Image
import io
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
img = Image.open(io.BytesIO(bytes(image)))
img.show()
